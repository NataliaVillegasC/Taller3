# %%
import pandas as pd

# %%
data = pd.read_csv('real_estate_valuation_data_set.csv', index_col=0)

# %%
data.shape
# Out:
# (414, 7)

# %%
data.head()
# Out:
#     X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# No
# 1              2012.917          32.0                                84.87882
# 2              2012.917          19.5                               306.59470
# 3              2013.583          13.3                               561.98450
# 4              2013.500          13.3                               561.98450
# 5              2012.833           5.0                               390.56840
#
#     X4 number of convenience stores  X5 latitude  X6 longitude  \
# No
# 1                                10     24.98298     121.54024
# 2                                 9     24.98034     121.53951
# 3                                 5     24.98746     121.54391
# 4                                 5     24.98746     121.54391
# 5                                 5     24.97937     121.54245
#
#     Y house price of unit area
# No
# 1                         37.9
# 2                         42.2
# 3                         47.3
# 4                         54.8
# 5                         43.1

# %% [markdown]
# - **X1 Transaction Date**: fecha de transacció de la casa
# - **X2 House Agre**: edad de la casa (tiempo desde su construcción)
# - **X3 Distance to the nearest MRT Station**: que tan cercana es la casa a una estacion de trasnporte público
# - **X4 Number of convenience stores**: número de tiendas de conveniencia cercanas
# - **X5 Latitude**: latitud
# - **X6 Longitude**: longitud
#
# - **Y House Price of unit area**: precio de la casa por unidad de área

# %% [markdown]
# ### Estadísticas descriptivas

# %%
data.describe()
# Out:
#        X1 transaction date  X2 house age  \
# count           414.000000    414.000000
# mean           2013.148971     17.712560
# std               0.281967     11.392485
# min            2012.667000      0.000000
# 25%            2012.917000      9.025000
# 50%            2013.167000     16.100000
# 75%            2013.417000     28.150000
# max            2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                       414.000000   414.000000    414.000000
# mean                          4.094203    24.969030    121.533361
# std                           2.945562     0.012410      0.015347
# min                           0.000000    24.932070    121.473530
# 25%                           1.000000    24.963000    121.528085
# 50%                           4.000000    24.971100    121.538630
# 75%                           6.000000    24.977455    121.543305
# max                          10.000000    25.014590    121.566270
#
#        Y house price of unit area
# count                  414.000000
# mean                    37.980193
# std                     13.606488
# min                      7.600000
# 25%                     27.700000
# 50%                     38.450000
# 75%                     46.600000
# max                    117.500000

# %% [markdown]
# ### Incluir seaborn para Visualización

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# ### Histogramas por cada variable y dispersión entre variables

# %%
sns.pairplot(data,)

# %% [markdown]
# ### Matriz de correlación

# %%
import seaborn as sb
corr = data.corr()
sb.heatmap(corr, cmap="RdPu", annot=True)
# Out:
# <Axes: >

# %%
corrw = data.drop(['Y house price of unit area'], axis=1).corrwith(data['Y house price of unit area'])
sb.heatmap(pd.DataFrame(corrw), cmap="RdPu", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Diagramas de dispersión y tendencia entre variables de entrada y variable de respuesta

# %%
sns.pairplot(data, x_vars=['X1 transaction date', 'X2 house age', 'X3 distance to the nearest MRT station', 'X4 number of convenience stores', 'X5 latitude', 'X6 longitude'], y_vars='Y house price of unit area', height=7, aspect=0.7, kind='reg')

# %% [markdown]
# ### Modelo de regresión
#
# $y = \beta_0 + \beta_1 \times \text{X1 transaction date} + \beta_2 \times \text{X2 house age} + \beta_3 \times \text{X3 distance to the nearest MRT station}$ + $\beta_4 \times \text{X4 number of convenience stores} + \beta_5 \times \text{X5 latitude} + \beta_6 \times \text{X6 longitude}$

# %%
# nombres de características
features = ['X1 transaction date', 'X2 house age', 'X3 distance to the nearest MRT station', 'X4 number of convenience stores', 'X5 latitude', 'X6 longitude']

# dataframe de características
X = data[features]

X.head()
# Out:
#     X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# No
# 1              2012.917          32.0                                84.87882
# 2              2012.917          19.5                               306.59470
# 3              2013.583          13.3                               561.98450
# 4              2013.500          13.3                               561.98450
# 5              2012.833           5.0                               390.56840
#
#     X4 number of convenience stores  X5 latitude  X6 longitude
# No
# 1                                10     24.98298     121.54024
# 2                                 9     24.98034     121.53951
# 3                                 5     24.98746     121.54391
# 4                                 5     24.98746     121.54391
# 5                                 5     24.97937     121.54245

# %%
X.shape
# Out:
# (414, 6)

# %%
# variable de respuesta
y = data['Y house price of unit area']

y.head()
# Out:
# No
# 1    37.9
# 2    42.2
# 3    47.3
# 4    54.8
# 5    43.1
# Name: Y house price of unit area, dtype: float64

# %%
# tipos de X y y
print(type(X))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### División entre entrenamiento y prueba

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# tamaños 
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (310, 6)
# (310,)
# (104, 6)
# (104,)

# %%
print(X.head())
print(X_train.head())
# Out:
#     X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# No
# 1              2012.917          32.0                                84.87882
# 2              2012.917          19.5                               306.59470
# 3              2013.583          13.3                               561.98450
# 4              2013.500          13.3                               561.98450
# 5              2012.833           5.0                               390.56840
#
#     X4 number of convenience stores  X5 latitude  X6 longitude
# No
# 1                                10     24.98298     121.54024
# 2                                 9     24.98034     121.53951
# 3                                 5     24.98746     121.54391
# 4                                 5     24.98746     121.54391
# 5                                 5     24.97937     121.54245
#      X1 transaction date  X2 house age  \
# No
# 369             2013.417          18.2
# 219             2013.417          13.6
# 128             2013.250           3.8
# 352             2012.833           4.0
# 174             2013.083          41.3
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# No
# 369                                350.8515                                1
# 219                                492.2313                                5
# 128                                383.8624                                5
# 352                               2180.2450                                3
# 174                                401.8807                                4
#
#      X5 latitude  X6 longitude
# No
# 369     24.97544     121.53119
# 219     24.96515     121.53737
# 128     24.98085     121.54391
# 352     24.96324     121.51241
# 174     24.98326     121.54460

# %%
# cambiando el tamaño del conjunto de prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

# %%
# tamaños 
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (331, 6)
# (331,)
# (83, 6)
# (83,)

# %%
# sin reordenar los datos
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, shuffle=False)

# %%
print(X.head())
print(X_train.head())
# Out:
#     X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# No
# 1              2012.917          32.0                                84.87882
# 2              2012.917          19.5                               306.59470
# 3              2013.583          13.3                               561.98450
# 4              2013.500          13.3                               561.98450
# 5              2012.833           5.0                               390.56840
#
#     X4 number of convenience stores  X5 latitude  X6 longitude
# No
# 1                                10     24.98298     121.54024
# 2                                 9     24.98034     121.53951
# 3                                 5     24.98746     121.54391
# 4                                 5     24.98746     121.54391
# 5                                 5     24.97937     121.54245
#     X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# No
# 1              2012.917          32.0                                84.87882
# 2              2012.917          19.5                               306.59470
# 3              2013.583          13.3                               561.98450
# 4              2013.500          13.3                               561.98450
# 5              2012.833           5.0                               390.56840
#
#     X4 number of convenience stores  X5 latitude  X6 longitude
# No
# 1                                10     24.98298     121.54024
# 2                                 9     24.98034     121.53951
# 3                                 5     24.98746     121.54391
# 4                                 5     24.98746     121.54391
# 5                                 5     24.97937     121.54245

# %%
# tamaños 
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (310, 6)
# (310,)
# (104, 6)
# (104,)

# %%
# volviendo al caso en que cambia el tamaño del conjunto de prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# crear el objeto del modelo
linreg = LinearRegression()

# ajustar los parámetros del modelo usando los datos de entrenamiento
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# imprimir coeficientes
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# -12796.117684899287
# [ 5.71714218e+00 -2.49326467e-01 -4.93769843e-03  1.07614509e+00
#   2.27037100e+02 -3.56988335e+01]

# %%
# coeficientes con nombre de las características
list(zip(features, linreg.coef_))
# Out:
# [('X1 transaction date', np.float64(5.7171421836102745)),
#  ('X2 house age', np.float64(-0.24932646689585264)),
#  ('X3 distance to the nearest MRT station', np.float64(-0.004937698432022964)),
#  ('X4 number of convenience stores', np.float64(1.0761450934453074)),
#  ('X5 latitude', np.float64(227.03710037116494)),
#  ('X6 longitude', np.float64(-35.69883346505084))]

# %% [markdown]
# ### Predicciones usando los datos de prueba

# %%
y_pred = linreg.predict(X_test)

# %% [markdown]
# ### Evaluar el modelo

# %% [markdown]
# **Error absoluto medio**:
#
# $$\text{MAE} = \frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Error cuadrado medio**:
# $$\text{MSE} = \frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Raíz del Error cuadrado medio**:
# $$\text{RMSE} = \sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$

# %%
from sklearn import metrics

# %%
import numpy as np

# mean absolute error
MAE = metrics.mean_absolute_error(y_test, y_pred)

# mean squared error
MSE = metrics.mean_squared_error(y_test, y_pred)

# root mean squared error
RMSE = np.sqrt(MSE)

# %%
print("MAE: ", MAE)
print("MSE: ", MSE)
print("RMSE: ", RMSE)
# Out:
# MAE:  5.343030944663339
# MSE:  45.01050719519749
# RMSE:  6.708987046879543

# %% [markdown]
# ### Validación cruzada

# %%
from sklearn.model_selection import cross_val_score

# usar MSE - error cuadrático medio
scores = cross_val_score(linreg, X, y, cv=5, scoring='neg_mean_squared_error')
mse_scores = - scores
print(mse_scores)
# Out:
# [ 49.89813853  89.0294996   57.865991   134.82397694  60.0535528 ]

# %%
# calcular RMSE
rmse_scores = np.sqrt(mse_scores)
print(rmse_scores)
# Out:
# [ 7.06386145  9.43554448  7.6069699  11.61137274  7.74942274]

# %%
# MSE y RMSE promedio a través de todos los grupos
print("MSE Promedio", mse_scores.mean())
print("RMSE Promedio", rmse_scores.mean())
# Out:
# MSE Promedio 78.33423177467634
# RMSE Promedio 8.693434260346503

# %% [markdown]
# ### Selección de variables - Modelo con otro subconjunto de variables

# %%
featuresb = ['X2 house age', 'X3 distance to the nearest MRT station', 'X4 number of convenience stores', 'X5 latitude', 'X6 longitude']

X = data[featuresb]
y = data['Y house price of unit area']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

linreg.fit(X_train, y_train)

y_pred = linreg.predict(X_test)

MAE = metrics.mean_absolute_error(y_test, y_pred)
MSE = metrics.mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(MSE)

print("MAE: ", MAE)
print("MSE: ", MSE)
print("RMSE: ", RMSE)
# Out:
# MAE:  5.713009860551119
# MSE:  56.18950777026411
# RMSE:  7.495966099860919

# %% [markdown]
# ### Validación cruzada

# %%
from sklearn.model_selection import cross_val_score

# usar MSE - error cuadrático medio
scores = cross_val_score(linreg, X, y, cv=5, scoring='neg_mean_squared_error')
mse_scores = - scores
print(mse_scores)
# Out:
# [ 54.59490522  86.67775497  57.07068747 139.23842104  62.13711996]

# %%
# calcular RMSE
rmse_scores = np.sqrt(mse_scores)
print(rmse_scores)
# Out:
# [ 7.38883653  9.31008888  7.55451438 11.79993309  7.88271019]

# %%
# MSE y RMSE promedio a través de todos los grupos
print("MSE Promedio", mse_scores.mean())
print("RMSE Promedio", rmse_scores.mean())
# Out:
# MSE Promedio 79.94377773067227
# RMSE Promedio 8.787216614023704

# %% [markdown]
# ## Ahora usando statsmodels

# %%
import statsmodels.api as sm

features = ['X1 transaction date', 'X2 house age', 'X3 distance to the nearest MRT station', 'X4 number of convenience stores', 'X5 latitude', 'X6 longitude']

X = data[features]
y = data['Y house price of unit area']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# agregar constante explíticamente
X_train = sm.add_constant(X_train)

# regresión usando mínimos cuadrados ordinarios (ordinary least squares - OLS) 
model = sm.OLS(y_train, X_train).fit()

# resumen de resultados
print(model.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Y house price of unit area   R-squared:                       0.543
# Model:                                    OLS   Adj. R-squared:                  0.534
# Method:                         Least Squares   F-statistic:                     60.00
# Date:                        Tue, 27 Aug 2024   Prob (F-statistic):           1.05e-48
# Time:                                10:48:25   Log-Likelihood:                -1129.0
# No. Observations:                         310   AIC:                             2272.
# Df Residuals:                             303   BIC:                             2298.
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                  -1.093e+04   8496.772     -1.287      0.199   -2.77e+04    5786.448
# X1 transaction date                        5.1272      1.897      2.702      0.007       1.393       8.861
# X2 house age                              -0.2389      0.047     -5.135      0.000      -0.330      -0.147
# X3 distance to the nearest MRT station    -0.0049      0.001     -5.539      0.000      -0.007      -0.003
# X4 number of convenience stores            1.0709      0.231      4.630      0.000       0.616       1.526
# X5 latitude                              216.8963     52.484      4.133      0.000     113.618     320.175
# X6 longitude                             -39.1702     59.720     -0.656      0.512    -156.689      78.349
# ==============================================================================
# Omnibus:                      189.462   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2953.563
# Skew:                           2.181   Prob(JB):                         0.00
# Kurtosis:                      17.479   Cond. No.                     3.79e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Modelo sin la observación 271

# %%
X_train_dropx = X_train.drop(index=271)
Y_train_dropy = y_train.drop(index=271)

new_model = sm.OLS(Y_train_dropy, X_train_dropx).fit()

print(new_model.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Y house price of unit area   R-squared:                       0.599
# Model:                                    OLS   Adj. R-squared:                  0.591
# Method:                         Least Squares   F-statistic:                     75.08
# Date:                        Tue, 27 Aug 2024   Prob (F-statistic):           5.71e-57
# Time:                                10:48:25   Log-Likelihood:                -1088.0
# No. Observations:                         309   AIC:                             2190.
# Df Residuals:                             302   BIC:                             2216.
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                   -1.47e+04   7542.180     -1.949      0.052   -2.95e+04     141.895
# X1 transaction date                        4.5307      1.683      2.692      0.007       1.219       7.843
# X2 house age                              -0.2243      0.041     -5.434      0.000      -0.305      -0.143
# X3 distance to the nearest MRT station    -0.0041      0.001     -5.144      0.000      -0.006      -0.003
# X4 number of convenience stores            1.2938      0.206      6.266      0.000       0.887       1.700
# X5 latitude                              211.9768     46.521      4.557      0.000     120.431     303.523
# X6 longitude                               2.6908     53.129      0.051      0.960    -101.859     107.241
# ==============================================================================
# Omnibus:                       49.905   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              130.000
# Skew:                           0.752   Prob(JB):                     5.90e-29
# Kurtosis:                       5.799   Cond. No.                     3.79e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### El segundo modelo, sin Longitud

# %%
featuresb = ['X1 transaction date', 'X2 house age', 'X3 distance to the nearest MRT station', 'X4 number of convenience stores', 'X5 latitude']

X = data[featuresb]
y = data['Y house price of unit area']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# agregar constante explíticamente
X_train = sm.add_constant(X_train)

# regresión usando mínimos cuadrados ordinarios (ordinary least squares - OLS) 
model = sm.OLS(y_train, X_train).fit()

# resumen de resultados
print(model.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Y house price of unit area   R-squared:                       0.542
# Model:                                    OLS   Adj. R-squared:                  0.535
# Method:                         Least Squares   F-statistic:                     72.05
# Date:                        Tue, 27 Aug 2024   Prob (F-statistic):           1.46e-49
# Time:                                10:48:25   Log-Likelihood:                -1129.2
# No. Observations:                         310   AIC:                             2270.
# Df Residuals:                             304   BIC:                             2293.
# Df Model:                                   5
# Covariance Type:                    nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                  -1.586e+04   3963.736     -4.002      0.000   -2.37e+04   -8062.018
# X1 transaction date                        5.1497      1.895      2.717      0.007       1.420       8.879
# X2 house age                              -0.2373      0.046     -5.112      0.000      -0.329      -0.146
# X3 distance to the nearest MRT station    -0.0045      0.001     -7.597      0.000      -0.006      -0.003
# X4 number of convenience stores            1.0873      0.230      4.733      0.000       0.635       1.539
# X5 latitude                              221.7681     51.907      4.272      0.000     119.626     323.910
# ==============================================================================
# Omnibus:                      192.288   Durbin-Watson:                   2.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3076.312
# Skew:                           2.217   Prob(JB):                         0.00
# Kurtosis:                      17.782   Cond. No.                     1.77e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Modelo sin la observación 271

# %%
X_train_dropx = X_train.drop(index=271)
Y_train_dropy = y_train.drop(index=271)

new_model = sm.OLS(Y_train_dropy, X_train_dropx).fit()

print(new_model.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Y house price of unit area   R-squared:                       0.599
# Model:                                    OLS   Adj. R-squared:                  0.592
# Method:                         Least Squares   F-statistic:                     90.39
# Date:                        Tue, 27 Aug 2024   Prob (F-statistic):           5.70e-58
# Time:                                10:48:25   Log-Likelihood:                -1088.0
# No. Observations:                         309   AIC:                             2188.
# Df Residuals:                             303   BIC:                             2210.
# Df Model:                                   5
# Covariance Type:                    nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                  -1.436e+04   3514.467     -4.087      0.000   -2.13e+04   -7446.302
# X1 transaction date                        4.5295      1.680      2.696      0.007       1.223       7.835
# X2 house age                              -0.2244      0.041     -5.454      0.000      -0.305      -0.143
# X3 distance to the nearest MRT station    -0.0041      0.001     -7.832      0.000      -0.005      -0.003
# X4 number of convenience stores            1.2925      0.205      6.314      0.000       0.890       1.695
# X5 latitude                              211.6469     45.987      4.602      0.000     121.153     302.141
# ==============================================================================
# Omnibus:                       49.907   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              130.209
# Skew:                           0.752   Prob(JB):                     5.32e-29
# Kurtosis:                       5.802   Cond. No.                     1.77e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Determinar la influencia de las observaciones

# %%
fig = sm.graphics.influence_plot(model, criterion="cooks")

# %% [markdown]
# ### Determinar puntos de alta influencia con distancia de Cook y umbral $4/n$

# %%
# disntacia de Cook
model_cooksd = model.get_influence().cooks_distance[0]

# get length of df to obtain n
n = X_train.shape[0]

# umbral
critical_d = 4/n
print('Umbral con distancia de Cook:', critical_d)

# puntos que podrían ser ourliers con alta influencia
out_d = model_cooksd > critical_d

print(X_train.index[out_d], "\n", model_cooksd[out_d])
# Out:
# Umbral con distancia de Cook: 0.012903225806451613
# Index([313, 271, 106, 362, 345, 129, 48, 114, 117, 221, 149, 167, 127, 383,
#        387],
#       dtype='int64', name='No')
#  [0.06154703 0.21309099 0.01868677 0.02290004 0.02274654 0.02275256
#  0.02311492 0.02559993 0.02099477 0.04770419 0.0653493  0.01598439
#  0.02226782 0.01642899 0.01446638]

# %%
X_train[out_d]
# Out:
#      const  X1 transaction date  X2 house age  \
# No
# 313    1.0             2013.583          35.4
# 271    1.0             2013.333          10.8
# 106    1.0             2012.833           0.0
# 362    1.0             2013.083          41.4
# 345    1.0             2013.500          34.6
# 129    1.0             2013.083          41.3
# 48     1.0             2013.583          35.9
# 114    1.0             2013.333          14.8
# 117    1.0             2013.000          30.9
# 221    1.0             2013.333          37.2
# 149    1.0             2013.500          16.4
# 167    1.0             2013.417           0.0
# 127    1.0             2013.083          38.6
# 383    1.0             2013.000          16.3
# 387    1.0             2012.833           0.0
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# No
# 313                                318.5292                                9
# 271                                252.5822                                1
# 106                                292.9978                                6
# 362                                281.2050                                8
# 345                               3085.1700                                0
# 129                                124.9912                                6
# 48                                 640.7391                                3
# 114                                393.2606                                6
# 117                               6396.2830                                1
# 221                                186.5101                                9
# 149                               3780.5900                                0
# 167                                292.9978                                6
# 127                                804.6897                                4
# 383                               3529.5640                                0
# 387                                185.4296                                0
#
#      X5 latitude
# No
# 313     24.97071
# 271     24.97460
# 106     24.97744
# 362     24.97345
# 345     24.99800
# 129     24.96674
# 48      24.97563
# 114     24.96172
# 117     24.94375
# 221     24.97703
# 149     24.93293
# 167     24.97744
# 127     24.97838
# 383     24.93207
# 387     24.97110

# %%
y_train[out_d]
# Out:
# No
# 313     78.0
# 271    117.5
# 106     71.0
# 362     63.3
# 345     41.2
# 129     60.7
# 48      61.5
# 114      7.6
# 117     12.2
# 221     78.3
# 149     45.1
# 167     73.6
# 127     62.9
# 383     29.3
# 387     55.3
# Name: Y house price of unit area, dtype: float64
